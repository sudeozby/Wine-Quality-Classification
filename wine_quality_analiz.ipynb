# %%
import pandas as pd
print("Sistem Uyandı! Veri çekiliyor...")
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')
print("Veri Seti Boyutu:", df.shape)
df.head()

# %%
# Eğer bu dosya sol taraftaki klasöründe belirirse, zafer senindir!
df.to_csv("veri_kontrol.csv")
print("Dosya oluşturuldu, klasörüne bak Sude!")

# %% [markdown]
# ##VERİ ANALİZİ(EDA Exploraty Data Analysis)

# %%
print("Selam Sude, çıktı buraya gelmeli!")

# %%
#Verinin genel yapısı ve eksik veri kontrolü
print("Veri Bilgisi")
print(df.info())

print("\nEksik Veri Sayısı")
print(df.isnull().sum())
#sonuc 0 ise eksik veri yok demektir

print("\nİstatistiksel Özet")
# display yerine print kullanarak tabloyu zorlayalım
print(df.describe())
#outlier deger kontrol ediyo
